# %% [markdown]
# <a href="https://colab.research.google.com/github/asso04/sentiment_analysis/blob/master/general_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
import numpy as np
import cv2
import os
import warnings
import sys
sys.stdout.write("\033[1;34m")
warnings.filterwarnings("ignore")
 
train_path_im='/content/drive/My Drive/GeneralYolodata/'
dir_path_conversation = '/content/drive/My Drive/chatterbot_dataset_ita'
len_data_vqa=2000
data_moltiplicator=2
input_im_size=64
num_epochs=2000
batch_size=128
 
#questions and answers
pre_ques = ['che cosa vedi']
pre_answers = ['vedo una camera da letto', 'vedo una città con dei palazzi', 'ci sono delle persone ',
               'una foresta con degli alberi', 'sono davanti ad una montagna', 'questo potrebbe essere un cane',
               'un gatto', 'il traffico con delle macchine', 'vedo una scrivania', 'questa dovrebbe essere una sedia']
questions = []
answers = []
 
for i in range(len_data_vqa):
    questions.append(pre_ques[0])
 
for i in range(int(len_data_vqa / 200)):
    for n in range(200):
        answers.append(pre_answers[i])
 
for i in range(data_moltiplicator):
 for filepath in os.listdir(dir_path_conversation):
    stream = open(dir_path_conversation + os.sep + filepath, 'r', encoding='utf-8')
    text = stream.readlines()
    for i in range(int(len(text) / 2) - 6):
        questions.append(text[i + i].rstrip('\n'))
        answers.append(text[i + i + 1].rstrip('\n'))
 
#images
images=[]
for i in range(len_data_vqa):
  i=i+1
  im=cv2.resize(cv2.imread(train_path_im+ str(i)+ '.jpg'),(input_im_size,input_im_size))/255.0
  images.append(im)
 
for i in range(len(questions)-len_data_vqa):
  im = cv2.resize(cv2.imread(train_path_im + 'faces_1.jpg'), (input_im_size, input_im_size)) / 255.0
  images.append(im)
 
images=np.expand_dims(images,1)
print('Images shape =',images.shape)
 
#questions
questions_lines = questions
 
tokenizer = Tokenizer()
tokenizer.fit_on_texts( questions_lines )
tokenized_eng_lines = tokenizer.texts_to_sequences( questions_lines )
 
length_list = []
for token_seq in tokenized_eng_lines:
    length_list.append( len( token_seq ))
max_input_length = np.amax( length_list )
print( 'questions max length is {}'.format( max_input_length ))
 
padded_eng_lines = pad_sequences( tokenized_eng_lines , maxlen=max_input_length , padding='post' )
encoder_input_data = np.array( np.expand_dims(padded_eng_lines, 1))
print( 'Encoder input data shape -> {}'.format( encoder_input_data.shape ))
 
eng_word_dict = tokenizer.word_index
num_eng_tokens = len( eng_word_dict )+1
print( 'Number of questions tokens = {}'.format( num_eng_tokens))
 
#answers
answer_lines = []
lines_answers=answers
for line in range( len(lines_answers)):
    answer_lines.append( '<START> ' + str(lines_answers[line]) + ' <END>' )
 
tokenizer = Tokenizer()
tokenizer.fit_on_texts( answer_lines )
tokenized_mar_lines = tokenizer.texts_to_sequences( answer_lines )
 
length_list = []
for token_seq in tokenized_mar_lines:
    length_list.append( len( token_seq ))
max_output_length = np.amax( length_list )
print( 'Answers max length is {}'.format( max_output_length ))
 
padded_mar_lines = pad_sequences( tokenized_mar_lines , maxlen=max_output_length, padding='post' )
decoder_input_data = np.array( padded_mar_lines )
print( 'Decoder input data shape -> {}'.format( decoder_input_data.shape ))
 
mar_word_dict = tokenizer.word_index
num_mar_tokens = len( mar_word_dict )+1
print( 'Number of Answers tokens = {}'.format( num_mar_tokens))
 
#decoder target data
decoder_target_data = list()
for token_seq in tokenized_mar_lines:
    decoder_target_data.append(token_seq[1:])
 
padded_mar_lines = pad_sequences(decoder_target_data, maxlen=max_output_length, padding='post')
onehot_mar_lines = to_categorical(padded_mar_lines, num_mar_tokens)
decoder_target_data = np.array(onehot_mar_lines)
print('Decoder target data shape -> {}'.format(decoder_target_data.shape))
 
#cnn model
vision_model=keras.models.Sequential()
vision_model.add(keras.layers.Conv2D(32, kernel_size=(3,3),padding='same',activation='elu',input_shape=(input_im_size,input_im_size,3)))
vision_model.add(keras.layers.Conv2D(32, kernel_size=(3,3),activation='elu'))
vision_model.add(keras.layers.MaxPooling2D((2,2)))
vision_model.add(keras.layers.Dropout(0.1))
vision_model.add(keras.layers.Conv2D(64, kernel_size=(3,3),padding='same',activation='elu'))
vision_model.add(keras.layers.Conv2D(64, kernel_size=(3,3),activation='elu'))
vision_model.add(keras.layers.MaxPooling2D((2,2)))
vision_model.add(keras.layers.Dropout(0.2))
vision_model.add(keras.layers.Conv2D(128,kernel_size=(3,3),padding='same',activation='elu'))
vision_model.add(keras.layers.Conv2D(128,kernel_size=(3,3),activation='elu'))
vision_model.add(keras.layers.Conv2D(128,kernel_size=(3,3),activation='elu'))
vision_model.add(keras.layers.MaxPooling2D((2,2)))
vision_model.add(keras.layers.Dropout(0.2))
vision_model.add(keras.layers.Flatten())
vision_model.add(keras.layers.BatchNormalization())
 
#seq2seq + cnn model
image_input=keras.layers.Input(shape=(1,input_im_size,input_im_size, 3))
cnn_lstm=keras.models.Sequential()
cnn_lstm.add(keras.layers.TimeDistributed(vision_model,input_shape=(1,input_im_size,input_im_size, 3)))
encoded_image=cnn_lstm(image_input)
 
encoder_inputs = keras.layers.Input(shape=( 1,None  ))
encoder_embedding = keras.layers.TimeDistributed(keras.layers.Embedding( num_eng_tokens, 128 , mask_zero=True ) )(encoder_inputs)
pre_lstm=keras.layers.TimeDistributed(keras.layers.LSTM( 64  ))(encoder_embedding)
merged=keras.layers.concatenate([encoded_image,pre_lstm])
encoder_outputs , state_h , state_c = keras.layers.LSTM( 64 , return_state=True  )(merged)
encoder_states = [ state_h , state_c ]
 
decoder_inputs = keras.layers.Input(shape=( None ,  ))
decoder_embedding = keras.layers.Embedding( num_mar_tokens, 128 , mask_zero=True) (decoder_inputs)
decoder_lstm = keras.layers.LSTM( 64 ,return_state=True,return_sequences=True)
decoder_outputs , _ , _ = decoder_lstm (decoder_embedding , initial_state=encoder_states )
decoder_dense = keras.layers.Dense( num_mar_tokens , activation=keras.activations.softmax )
output_0 = decoder_dense (decoder_outputs )
 
vqaseq_model=keras.models.Model([image_input,encoder_inputs,decoder_inputs],output_0)
 
#compile model
vqaseq_model.compile(
  optimizer=keras.optimizers.Adam(),
  loss='categorical_crossentropy',
  metrics=['accuracy'],
)
vqaseq_model.summary()
 
vqaseq_model.fit([images,encoder_input_data , decoder_input_data], decoder_target_data, batch_size=batch_size, epochs=num_epochs)
 
def make_inference_models():
    encoder_model = keras.models.Model([image_input,encoder_inputs], encoder_states)
 
    decoder_state_input_h = keras.layers.Input(shape=(64,))
    decoder_state_input_c = keras.layers.Input(shape=(64,))
 
    decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
 
    decoder_outputs_, state_h_, state_c_ = decoder_lstm(decoder_embedding, initial_state=decoder_states_inputs)
    decoder_states = [state_h_, state_c_]
    decoder_outputs_ = decoder_dense(decoder_outputs_)
    decoder_model = keras.models.Model([decoder_inputs] + decoder_states_inputs,[decoder_outputs_] + decoder_states)
 
    return encoder_model, decoder_model
 
def freeze(model):
    """Freeze model weights in every layer."""
    for layer in model.layers:
        layer.trainable = False
 
        if isinstance(layer, keras.models.Model):
            freeze(layer)
    return model
 
enc_model, dec_model = make_inference_models()
 
freeze(enc_model).save('enc_model.h5')
freeze(dec_model).save('dec_model.h5')
# Out:
# Images shape = (2100, 1, 64, 64, 3)
# questions max length is 12
# Encoder input data shape -> (2100, 1, 12)
# Number of questions tokens = 150
# Answers max length is 18
# Decoder input data shape -> (2100, 18)
# Number of Answers tokens = 185
# Decoder target data shape -> (2100, 18, 185)
# Model: "functional_19"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_25 (InputLayer)           [(None, 1, None)]    0
# __________________________________________________________________________________________________
# input_24 (InputLayer)           [(None, 1, 64, 64, 3 0
# __________________________________________________________________________________________________
# time_distributed_22 (TimeDistri (None, 1, None, 128) 19200       input_25[0][0]
# __________________________________________________________________________________________________
# sequential_15 (Sequential)      (None, 1, 3200)      447392      input_24[0][0]
# __________________________________________________________________________________________________
# time_distributed_23 (TimeDistri (None, 1, 64)        49408       time_distributed_22[0][0]
# __________________________________________________________________________________________________
# input_26 (InputLayer)           [(None, None)]       0
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 1, 3264)      0           sequential_15[0][0]
#                                                                  time_distributed_23[0][0]
# __________________________________________________________________________________________________
# embedding_15 (Embedding)        (None, None, 128)    23680       input_26[0][0]
# __________________________________________________________________________________________________
# lstm_22 (LSTM)                  [(None, 64), (None,  852224      concatenate_7[0][0]
# __________________________________________________________________________________________________
# lstm_23 (LSTM)                  [(None, None, 64), ( 49408       embedding_15[0][0]
#                                                                  lstm_22[0][1]
#                                                                  lstm_22[0][2]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, None, 185)    12025       lstm_23[0][0]
# ==================================================================================================
# Total params: 1,453,337
# Trainable params: 1,446,937
# Non-trainable params: 6,400
# __________________________________________________________________________________________________
# Epoch 1/2000
# 17/17 [==============================] - 1s 67ms/step - loss: 1.8219 - accuracy: 0.1213
# Epoch 2/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 1.4445 - accuracy: 0.1770
# Epoch 3/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 1.1358 - accuracy: 0.2290
# Epoch 4/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 1.0234 - accuracy: 0.2839
# Epoch 5/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.9371 - accuracy: 0.3662
# Epoch 6/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.8496 - accuracy: 0.4245
# Epoch 7/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.7629 - accuracy: 0.4751
# Epoch 8/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.6767 - accuracy: 0.5138
# Epoch 9/2000
# 17/17 [==============================] - 1s 66ms/step - loss: 0.5956 - accuracy: 0.5578
# Epoch 10/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.5206 - accuracy: 0.6551
# Epoch 11/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.4471 - accuracy: 0.7675
# Epoch 12/2000
# 17/17 [==============================] - 1s 66ms/step - loss: 0.3841 - accuracy: 0.8598
# Epoch 13/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.3306 - accuracy: 0.8741
# Epoch 14/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.2874 - accuracy: 0.8828
# Epoch 15/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.2527 - accuracy: 0.8914
# Epoch 16/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.2280 - accuracy: 0.8945
# Epoch 17/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.2084 - accuracy: 0.8950
# Epoch 18/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.1917 - accuracy: 0.9019
# Epoch 19/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.1782 - accuracy: 0.9056
# Epoch 20/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.1664 - accuracy: 0.9114
# Epoch 21/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.1585 - accuracy: 0.9113
# Epoch 22/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.1515 - accuracy: 0.9144
# Epoch 23/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.1433 - accuracy: 0.9181
# Epoch 24/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.1390 - accuracy: 0.9190
# Epoch 25/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.1326 - accuracy: 0.9224
# Epoch 26/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.1293 - accuracy: 0.9203
# Epoch 27/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.1227 - accuracy: 0.9253
# Epoch 28/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.1203 - accuracy: 0.9266
# Epoch 29/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.1156 - accuracy: 0.9304
# Epoch 30/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.1185 - accuracy: 0.9247
# Epoch 31/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.1129 - accuracy: 0.9302
# Epoch 32/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.1085 - accuracy: 0.9319
# Epoch 33/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.1040 - accuracy: 0.9349
# Epoch 34/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0996 - accuracy: 0.9394
# Epoch 35/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0959 - accuracy: 0.9421
# Epoch 36/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0909 - accuracy: 0.9458
# Epoch 37/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0879 - accuracy: 0.9482
# Epoch 38/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0850 - accuracy: 0.9491
# Epoch 39/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0841 - accuracy: 0.9486
# Epoch 40/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0805 - accuracy: 0.9515
# Epoch 41/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0767 - accuracy: 0.9542
# Epoch 42/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0732 - accuracy: 0.9569
# Epoch 43/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0707 - accuracy: 0.9583
# Epoch 44/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0689 - accuracy: 0.9590
# Epoch 45/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0665 - accuracy: 0.9606
# Epoch 46/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0639 - accuracy: 0.9622
# Epoch 47/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0604 - accuracy: 0.9647
# Epoch 48/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0580 - accuracy: 0.9665
# Epoch 49/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0569 - accuracy: 0.9668
# Epoch 50/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0555 - accuracy: 0.9674
# Epoch 51/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0533 - accuracy: 0.9688
# Epoch 52/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0513 - accuracy: 0.9709
# Epoch 53/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0491 - accuracy: 0.9712
# Epoch 54/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0487 - accuracy: 0.9713
# Epoch 55/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0463 - accuracy: 0.9735
# Epoch 56/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0447 - accuracy: 0.9742
# Epoch 57/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0440 - accuracy: 0.9746
# Epoch 58/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0437 - accuracy: 0.9742
# Epoch 59/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0405 - accuracy: 0.9776
# Epoch 60/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0386 - accuracy: 0.9786
# Epoch 61/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0376 - accuracy: 0.9794
# Epoch 62/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0358 - accuracy: 0.9807
# Epoch 63/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0344 - accuracy: 0.9816
# Epoch 64/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0330 - accuracy: 0.9831
# Epoch 65/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0323 - accuracy: 0.9835
# Epoch 66/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0305 - accuracy: 0.9848
# Epoch 67/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0295 - accuracy: 0.9856
# Epoch 68/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0289 - accuracy: 0.9859
# Epoch 69/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0309 - accuracy: 0.9840
# Epoch 70/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0321 - accuracy: 0.9819
# Epoch 71/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0311 - accuracy: 0.9821
# Epoch 72/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0317 - accuracy: 0.9820
# Epoch 73/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0321 - accuracy: 0.9814
# Epoch 74/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0268 - accuracy: 0.9862
# Epoch 75/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0264 - accuracy: 0.9860
# Epoch 76/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0246 - accuracy: 0.9875
# Epoch 77/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0237 - accuracy: 0.9881
# Epoch 78/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0223 - accuracy: 0.9887
# Epoch 79/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0218 - accuracy: 0.9892
# Epoch 80/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0213 - accuracy: 0.9890
# Epoch 81/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0211 - accuracy: 0.9888
# Epoch 82/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0210 - accuracy: 0.9896
# Epoch 83/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0204 - accuracy: 0.9894
# Epoch 84/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0203 - accuracy: 0.9897
# Epoch 85/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0195 - accuracy: 0.9899
# Epoch 86/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0187 - accuracy: 0.9906
# Epoch 87/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0214 - accuracy: 0.9878
# Epoch 88/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0206 - accuracy: 0.9886
# Epoch 89/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0192 - accuracy: 0.9895
# Epoch 90/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0186 - accuracy: 0.9896
# Epoch 91/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0179 - accuracy: 0.9899
# Epoch 92/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0179 - accuracy: 0.9899
# Epoch 93/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0173 - accuracy: 0.9903
# Epoch 94/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0168 - accuracy: 0.9904
# Epoch 95/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0168 - accuracy: 0.9905
# Epoch 96/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0167 - accuracy: 0.9902
# Epoch 97/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0164 - accuracy: 0.9898
# Epoch 98/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0161 - accuracy: 0.9902
# Epoch 99/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0161 - accuracy: 0.9903
# Epoch 100/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0158 - accuracy: 0.9902
# Epoch 101/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0155 - accuracy: 0.9906
# Epoch 102/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0313 - accuracy: 0.9762
# Epoch 103/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0532 - accuracy: 0.9579
# Epoch 104/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0325 - accuracy: 0.9750
# Epoch 105/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0219 - accuracy: 0.9856
# Epoch 106/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0182 - accuracy: 0.9877
# Epoch 107/2000
# 17/17 [==============================] - 1s 66ms/step - loss: 0.0171 - accuracy: 0.9887
# Epoch 108/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0167 - accuracy: 0.9893
# Epoch 109/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0165 - accuracy: 0.9891
# Epoch 110/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0156 - accuracy: 0.9899
# Epoch 111/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0151 - accuracy: 0.9899
# Epoch 112/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0149 - accuracy: 0.9904
# Epoch 113/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0147 - accuracy: 0.9903
# Epoch 114/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0145 - accuracy: 0.9902
# Epoch 115/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0144 - accuracy: 0.9902
# Epoch 116/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0141 - accuracy: 0.9907
# Epoch 117/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0140 - accuracy: 0.9904
# Epoch 118/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0141 - accuracy: 0.9902
# Epoch 119/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0139 - accuracy: 0.9901
# Epoch 120/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0135 - accuracy: 0.9903
# Epoch 121/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0136 - accuracy: 0.9902
# Epoch 122/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0135 - accuracy: 0.9906
# Epoch 123/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0133 - accuracy: 0.9905
# Epoch 124/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0132 - accuracy: 0.9907
# Epoch 125/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0132 - accuracy: 0.9908
# Epoch 126/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0131 - accuracy: 0.9907
# Epoch 127/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0130 - accuracy: 0.9905
# Epoch 128/2000
# 17/17 [==============================] - 1s 66ms/step - loss: 0.0128 - accuracy: 0.9908
# Epoch 129/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0129 - accuracy: 0.9902
# Epoch 130/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0129 - accuracy: 0.9907
# Epoch 131/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0129 - accuracy: 0.9907
# Epoch 132/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0128 - accuracy: 0.9905
# Epoch 133/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0127 - accuracy: 0.9906
# Epoch 134/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0132 - accuracy: 0.9900
# Epoch 135/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0135 - accuracy: 0.9897
# Epoch 136/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0137 - accuracy: 0.9897
# Epoch 137/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0133 - accuracy: 0.9899
# Epoch 138/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0129 - accuracy: 0.9902
# Epoch 139/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0129 - accuracy: 0.9903
# Epoch 140/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0125 - accuracy: 0.9905
# Epoch 141/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0124 - accuracy: 0.9906
# Epoch 142/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0123 - accuracy: 0.9905
# Epoch 143/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0123 - accuracy: 0.9907
# Epoch 144/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0123 - accuracy: 0.9905
# Epoch 145/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0122 - accuracy: 0.9907
# Epoch 146/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0121 - accuracy: 0.9909
# Epoch 147/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0121 - accuracy: 0.9907
# Epoch 148/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0121 - accuracy: 0.9904
# Epoch 149/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0125 - accuracy: 0.9902
# Epoch 150/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0136 - accuracy: 0.9894
# Epoch 151/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0141 - accuracy: 0.9887
# Epoch 152/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0134 - accuracy: 0.9892
# Epoch 153/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0137 - accuracy: 0.9894
# Epoch 154/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0132 - accuracy: 0.9897
# Epoch 155/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0132 - accuracy: 0.9892
# Epoch 156/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0134 - accuracy: 0.9896
# Epoch 157/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0137 - accuracy: 0.9891
# Epoch 158/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0133 - accuracy: 0.9891
# Epoch 159/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0125 - accuracy: 0.9900
# Epoch 160/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0125 - accuracy: 0.9899
# Epoch 161/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0123 - accuracy: 0.9902
# Epoch 162/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0119 - accuracy: 0.9906
# Epoch 163/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0119 - accuracy: 0.9905
# Epoch 164/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0119 - accuracy: 0.9906
# Epoch 165/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0120 - accuracy: 0.9905
# Epoch 166/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0119 - accuracy: 0.9907
# Epoch 167/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0118 - accuracy: 0.9901
# Epoch 168/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0119 - accuracy: 0.9901
# Epoch 169/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0119 - accuracy: 0.9902
# Epoch 170/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0118 - accuracy: 0.9902
# Epoch 171/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0121 - accuracy: 0.9902
# Epoch 172/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0121 - accuracy: 0.9901
# Epoch 173/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0126 - accuracy: 0.9902
# Epoch 174/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0753 - accuracy: 0.9463
# Epoch 175/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0906 - accuracy: 0.9200
# Epoch 176/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0690 - accuracy: 0.9342
# Epoch 177/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0447 - accuracy: 0.9603
# Epoch 178/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0290 - accuracy: 0.9738
# Epoch 179/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0219 - accuracy: 0.9816
# Epoch 180/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0177 - accuracy: 0.9853
# Epoch 181/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0153 - accuracy: 0.9880
# Epoch 182/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0170 - accuracy: 0.9858
# Epoch 183/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0143 - accuracy: 0.9886
# Epoch 184/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0138 - accuracy: 0.9891
# Epoch 185/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0129 - accuracy: 0.9899
# Epoch 186/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0126 - accuracy: 0.9902
# Epoch 187/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0125 - accuracy: 0.9902
# Epoch 188/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0124 - accuracy: 0.9901
# Epoch 189/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0127 - accuracy: 0.9902
# Epoch 190/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0121 - accuracy: 0.9902
# Epoch 191/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0121 - accuracy: 0.9902
# Epoch 192/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0122 - accuracy: 0.9900
# Epoch 193/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0121 - accuracy: 0.9898
# Epoch 194/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0121 - accuracy: 0.9905
# Epoch 195/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0120 - accuracy: 0.9904
# Epoch 196/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0121 - accuracy: 0.9902
# Epoch 197/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0118 - accuracy: 0.9904
# Epoch 198/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0120 - accuracy: 0.9902
# Epoch 199/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0117 - accuracy: 0.9905
# Epoch 200/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0116 - accuracy: 0.9907
# Epoch 201/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0114 - accuracy: 0.9909
# Epoch 202/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0114 - accuracy: 0.9906
# Epoch 203/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0114 - accuracy: 0.9906
# Epoch 204/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0134 - accuracy: 0.9894
# Epoch 205/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0121 - accuracy: 0.9897
# Epoch 206/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0124 - accuracy: 0.9897
# Epoch 207/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0122 - accuracy: 0.9901
# Epoch 208/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0116 - accuracy: 0.9901
# Epoch 209/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0116 - accuracy: 0.9902
# Epoch 210/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0115 - accuracy: 0.9905
# Epoch 211/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0114 - accuracy: 0.9903
# Epoch 212/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0113 - accuracy: 0.9905
# Epoch 213/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0114 - accuracy: 0.9902
# Epoch 214/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0112 - accuracy: 0.9904
# Epoch 215/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0114 - accuracy: 0.9905
# Epoch 216/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0112 - accuracy: 0.9907
# Epoch 217/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0112 - accuracy: 0.9909
# Epoch 218/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0114 - accuracy: 0.9905
# Epoch 219/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0113 - accuracy: 0.9900
# Epoch 220/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0112 - accuracy: 0.9904
# Epoch 221/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0111 - accuracy: 0.9905
# Epoch 222/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0112 - accuracy: 0.9904
# Epoch 223/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0111 - accuracy: 0.9907
# Epoch 224/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0112 - accuracy: 0.9906
# Epoch 225/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0113 - accuracy: 0.9907
# Epoch 226/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0111 - accuracy: 0.9906
# Epoch 227/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0113 - accuracy: 0.9905
# Epoch 228/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0113 - accuracy: 0.9906
# Epoch 229/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0114 - accuracy: 0.9905
# Epoch 230/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0116 - accuracy: 0.9905
# Epoch 231/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0112 - accuracy: 0.9907
# Epoch 232/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0117 - accuracy: 0.9902
# Epoch 233/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0116 - accuracy: 0.9899
# Epoch 234/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0118 - accuracy: 0.9899
# Epoch 235/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0113 - accuracy: 0.9902
# Epoch 236/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0113 - accuracy: 0.9904
# Epoch 237/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0112 - accuracy: 0.9903
# Epoch 238/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0115 - accuracy: 0.9897
# Epoch 239/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0113 - accuracy: 0.9902
# Epoch 240/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0113 - accuracy: 0.9905
# Epoch 241/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0113 - accuracy: 0.9902
# Epoch 242/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0112 - accuracy: 0.9905
# Epoch 243/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0113 - accuracy: 0.9905
# Epoch 244/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0111 - accuracy: 0.9905
# Epoch 245/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0112 - accuracy: 0.9907
# Epoch 246/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0112 - accuracy: 0.9905
# Epoch 247/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0113 - accuracy: 0.9904
# Epoch 248/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0115 - accuracy: 0.9903
# Epoch 249/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0116 - accuracy: 0.9901
# Epoch 250/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0112 - accuracy: 0.9902
# Epoch 251/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0113 - accuracy: 0.9904
# Epoch 252/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0111 - accuracy: 0.9907
# Epoch 253/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0109 - accuracy: 0.9907
# Epoch 254/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0109 - accuracy: 0.9907
# Epoch 255/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0110 - accuracy: 0.9905
# Epoch 256/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0111 - accuracy: 0.9902
# Epoch 257/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0111 - accuracy: 0.9903
# Epoch 258/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0110 - accuracy: 0.9907
# Epoch 259/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0110 - accuracy: 0.9907
# Epoch 260/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0109 - accuracy: 0.9905
# Epoch 261/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0110 - accuracy: 0.9907
# Epoch 262/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0111 - accuracy: 0.9907
# Epoch 263/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0113 - accuracy: 0.9902
# Epoch 264/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0111 - accuracy: 0.9907
# Epoch 265/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0110 - accuracy: 0.9906
# Epoch 266/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0111 - accuracy: 0.9903
# Epoch 267/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0110 - accuracy: 0.9906
# Epoch 268/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0113 - accuracy: 0.9903
# Epoch 269/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0134 - accuracy: 0.9888
# Epoch 270/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0120 - accuracy: 0.9896
# Epoch 271/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0123 - accuracy: 0.9895
# Epoch 272/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0118 - accuracy: 0.9898
# Epoch 273/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0145 - accuracy: 0.9875
# Epoch 274/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0128 - accuracy: 0.9890
# Epoch 275/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0125 - accuracy: 0.9892
# Epoch 276/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0114 - accuracy: 0.9905
# Epoch 277/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0113 - accuracy: 0.9902
# Epoch 278/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0110 - accuracy: 0.9905
# Epoch 279/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0112 - accuracy: 0.9902
# Epoch 280/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0111 - accuracy: 0.9904
# Epoch 281/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0111 - accuracy: 0.9903
# Epoch 282/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0111 - accuracy: 0.9904
# Epoch 283/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0114 - accuracy: 0.9901
# Epoch 284/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0109 - accuracy: 0.9906
# Epoch 285/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0110 - accuracy: 0.9903
# Epoch 286/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0112 - accuracy: 0.9899
# Epoch 287/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0111 - accuracy: 0.9907
# Epoch 288/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0115 - accuracy: 0.9899
# Epoch 289/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0114 - accuracy: 0.9901
# Epoch 290/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0115 - accuracy: 0.9896
# Epoch 291/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0118 - accuracy: 0.9897
# Epoch 292/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0113 - accuracy: 0.9902
# Epoch 293/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0113 - accuracy: 0.9899
# Epoch 294/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0112 - accuracy: 0.9905
# Epoch 295/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0122 - accuracy: 0.9895
# Epoch 296/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0125 - accuracy: 0.9885
# Epoch 297/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0130 - accuracy: 0.9891
# Epoch 298/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0115 - accuracy: 0.9898
# Epoch 299/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0115 - accuracy: 0.9902
# Epoch 300/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0115 - accuracy: 0.9901
# Epoch 301/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0111 - accuracy: 0.9903
# Epoch 302/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0110 - accuracy: 0.9904
# Epoch 303/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0113 - accuracy: 0.9902
# Epoch 304/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0122 - accuracy: 0.9891
# Epoch 305/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0112 - accuracy: 0.9904
# Epoch 306/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0111 - accuracy: 0.9905
# Epoch 307/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0109 - accuracy: 0.9905
# Epoch 308/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0109 - accuracy: 0.9907
# Epoch 309/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0110 - accuracy: 0.9902
# Epoch 310/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0108 - accuracy: 0.9904
# Epoch 311/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0108 - accuracy: 0.9905
# Epoch 312/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0108 - accuracy: 0.9908
# Epoch 313/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0108 - accuracy: 0.9903
# Epoch 314/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0108 - accuracy: 0.9906
# Epoch 315/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0108 - accuracy: 0.9905
# Epoch 316/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0108 - accuracy: 0.9904
# Epoch 317/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0108 - accuracy: 0.9907
# Epoch 318/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0107 - accuracy: 0.9906
# Epoch 319/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0108 - accuracy: 0.9907
# Epoch 320/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0108 - accuracy: 0.9906
# Epoch 321/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0107 - accuracy: 0.9906
# Epoch 322/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0108 - accuracy: 0.9903
# Epoch 323/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0109 - accuracy: 0.9902
# Epoch 324/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0110 - accuracy: 0.9905
# Epoch 325/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0109 - accuracy: 0.9904
# Epoch 326/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0108 - accuracy: 0.9907
# Epoch 327/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0108 - accuracy: 0.9902
# Epoch 328/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0108 - accuracy: 0.9903
# Epoch 329/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0107 - accuracy: 0.9903
# Epoch 330/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0108 - accuracy: 0.9907
# Epoch 331/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0108 - accuracy: 0.9905
# Epoch 332/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0110 - accuracy: 0.9902
# Epoch 333/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0108 - accuracy: 0.9905
# Epoch 334/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0107 - accuracy: 0.9905
# Epoch 335/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0107 - accuracy: 0.9907
# Epoch 336/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0107 - accuracy: 0.9906
# Epoch 337/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0108 - accuracy: 0.9905
# Epoch 338/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0107 - accuracy: 0.9908
# Epoch 339/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0108 - accuracy: 0.9906
# Epoch 340/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0109 - accuracy: 0.9907
# Epoch 341/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0107 - accuracy: 0.9905
# Epoch 342/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0107 - accuracy: 0.9907
# Epoch 343/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0107 - accuracy: 0.9907
# Epoch 344/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0110 - accuracy: 0.9901
# Epoch 345/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0108 - accuracy: 0.9905
# Epoch 346/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0108 - accuracy: 0.9905
# Epoch 347/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0110 - accuracy: 0.9901
# Epoch 348/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0107 - accuracy: 0.9908
# Epoch 349/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0106 - accuracy: 0.9907
# Epoch 350/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0108 - accuracy: 0.9904
# Epoch 351/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0108 - accuracy: 0.9901
# Epoch 352/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0107 - accuracy: 0.9907
# Epoch 353/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0108 - accuracy: 0.9907
# Epoch 354/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0108 - accuracy: 0.9908
# Epoch 355/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0109 - accuracy: 0.9902
# Epoch 356/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0107 - accuracy: 0.9907
# Epoch 357/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0108 - accuracy: 0.9905
# Epoch 358/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0109 - accuracy: 0.9900
# Epoch 359/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0108 - accuracy: 0.9905
# Epoch 360/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0110 - accuracy: 0.9903
# Epoch 361/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0109 - accuracy: 0.9903
# Epoch 362/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0107 - accuracy: 0.9906
# Epoch 363/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0108 - accuracy: 0.9903
# Epoch 364/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0109 - accuracy: 0.9902
# Epoch 365/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0125 - accuracy: 0.9888
# Epoch 366/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0113 - accuracy: 0.9899
# Epoch 367/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0116 - accuracy: 0.9891
# Epoch 368/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0121 - accuracy: 0.9894
# Epoch 369/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0124 - accuracy: 0.9891
# Epoch 370/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0124 - accuracy: 0.9889
# Epoch 371/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0119 - accuracy: 0.9896
# Epoch 372/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0123 - accuracy: 0.9893
# Epoch 373/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0119 - accuracy: 0.9893
# Epoch 374/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0120 - accuracy: 0.9891
# Epoch 375/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0122 - accuracy: 0.9891
# Epoch 376/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0115 - accuracy: 0.9902
# Epoch 377/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0113 - accuracy: 0.9902
# Epoch 378/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0109 - accuracy: 0.9906
# Epoch 379/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0107 - accuracy: 0.9907
# Epoch 380/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0109 - accuracy: 0.9902
# Epoch 381/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0108 - accuracy: 0.9907
# Epoch 382/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0108 - accuracy: 0.9902
# Epoch 383/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0110 - accuracy: 0.9903
# Epoch 384/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0108 - accuracy: 0.9906
# Epoch 385/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0107 - accuracy: 0.9906
# Epoch 386/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0107 - accuracy: 0.9903
# Epoch 387/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0107 - accuracy: 0.9907
# Epoch 388/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0106 - accuracy: 0.9905
# Epoch 389/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0107 - accuracy: 0.9902
# Epoch 390/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0106 - accuracy: 0.9905
# Epoch 391/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0106 - accuracy: 0.9906
# Epoch 392/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0106 - accuracy: 0.9907
# Epoch 393/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0108 - accuracy: 0.9907
# Epoch 394/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0115 - accuracy: 0.9901
# Epoch 395/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0120 - accuracy: 0.9897
# Epoch 396/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0121 - accuracy: 0.9897
# Epoch 397/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0124 - accuracy: 0.9895
# Epoch 398/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0121 - accuracy: 0.9895
# Epoch 399/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0115 - accuracy: 0.9899
# Epoch 400/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0117 - accuracy: 0.9895
# Epoch 401/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0115 - accuracy: 0.9897
# Epoch 402/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0114 - accuracy: 0.9901
# Epoch 403/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0114 - accuracy: 0.9899
# Epoch 404/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0113 - accuracy: 0.9901
# Epoch 405/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0115 - accuracy: 0.9898
# Epoch 406/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0113 - accuracy: 0.9900
# Epoch 407/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0111 - accuracy: 0.9901
# Epoch 408/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0114 - accuracy: 0.9899
# Epoch 409/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0108 - accuracy: 0.9904
# Epoch 410/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0107 - accuracy: 0.9904
# Epoch 411/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0107 - accuracy: 0.9904
# Epoch 412/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0107 - accuracy: 0.9903
# Epoch 413/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0109 - accuracy: 0.9899
# Epoch 414/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0109 - accuracy: 0.9905
# Epoch 415/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0106 - accuracy: 0.9905
# Epoch 416/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0107 - accuracy: 0.9903
# Epoch 417/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0107 - accuracy: 0.9903
# Epoch 418/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0107 - accuracy: 0.9903
# Epoch 419/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0107 - accuracy: 0.9902
# Epoch 420/2000
# 17/17 [==============================] - 1s 66ms/step - loss: 0.0106 - accuracy: 0.9905
# Epoch 421/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0107 - accuracy: 0.9902
# Epoch 422/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0110 - accuracy: 0.9903
# Epoch 423/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0120 - accuracy: 0.9896
# Epoch 424/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0123 - accuracy: 0.9895
# Epoch 425/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0121 - accuracy: 0.9891
# Epoch 426/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0120 - accuracy: 0.9889
# Epoch 427/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0119 - accuracy: 0.9893
# Epoch 428/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0116 - accuracy: 0.9892
# Epoch 429/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0114 - accuracy: 0.9897
# Epoch 430/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0110 - accuracy: 0.9902
# Epoch 431/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0109 - accuracy: 0.9904
# Epoch 432/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0114 - accuracy: 0.9899
# Epoch 433/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0113 - accuracy: 0.9902
# Epoch 434/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0108 - accuracy: 0.9902
# Epoch 435/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0106 - accuracy: 0.9907
# Epoch 436/2000
# ...
# Epoch 1849/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 9.4979e-04 - accuracy: 0.9988
# Epoch 1850/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0011 - accuracy: 0.9988
# Epoch 1851/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 9.0129e-04 - accuracy: 0.9991
# Epoch 1852/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 8.1113e-04 - accuracy: 0.9992
# Epoch 1853/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 8.8871e-04 - accuracy: 0.9988
# Epoch 1854/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 8.2410e-04 - accuracy: 0.9989
# Epoch 1855/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 8.0568e-04 - accuracy: 0.9990
# Epoch 1856/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 8.4690e-04 - accuracy: 0.9989
# Epoch 1857/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 9.3850e-04 - accuracy: 0.9991
# Epoch 1858/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 8.6617e-04 - accuracy: 0.9988
# Epoch 1859/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0010 - accuracy: 0.9990
# Epoch 1860/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0010 - accuracy: 0.9989
# Epoch 1861/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 9.0011e-04 - accuracy: 0.9991
# Epoch 1862/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 7.9917e-04 - accuracy: 0.9992
# Epoch 1863/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 9.1543e-04 - accuracy: 0.9990
# Epoch 1864/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0011 - accuracy: 0.9988
# Epoch 1865/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0012 - accuracy: 0.9988
# Epoch 1866/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0012 - accuracy: 0.9986
# Epoch 1867/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0012 - accuracy: 0.9988
# Epoch 1868/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0014 - accuracy: 0.9986
# Epoch 1869/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0015 - accuracy: 0.9980
# Epoch 1870/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0011 - accuracy: 0.9986
# Epoch 1871/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0013 - accuracy: 0.9984
# Epoch 1872/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0011 - accuracy: 0.9988
# Epoch 1873/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0010 - accuracy: 0.9988
# Epoch 1874/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 8.5995e-04 - accuracy: 0.9990
# Epoch 1875/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0010 - accuracy: 0.9986
# Epoch 1876/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 7.8907e-04 - accuracy: 0.9990
# Epoch 1877/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 9.7940e-04 - accuracy: 0.9988
# Epoch 1878/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 8.0229e-04 - accuracy: 0.9992
# Epoch 1879/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 9.8929e-04 - accuracy: 0.9986
# Epoch 1880/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 8.8416e-04 - accuracy: 0.9988
# Epoch 1881/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 9.3716e-04 - accuracy: 0.9988
# Epoch 1882/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 8.2534e-04 - accuracy: 0.9990
# Epoch 1883/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 7.9182e-04 - accuracy: 0.9990
# Epoch 1884/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 8.4269e-04 - accuracy: 0.9992
# Epoch 1885/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 8.1968e-04 - accuracy: 0.9990
# Epoch 1886/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 7.5246e-04 - accuracy: 0.9993
# Epoch 1887/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 7.2428e-04 - accuracy: 0.9991
# Epoch 1888/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 7.6269e-04 - accuracy: 0.9992
# Epoch 1889/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 9.4621e-04 - accuracy: 0.9989
# Epoch 1890/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0015 - accuracy: 0.9985
# Epoch 1891/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0019 - accuracy: 0.9980
# Epoch 1892/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0012 - accuracy: 0.9987
# Epoch 1893/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 8.8972e-04 - accuracy: 0.9989
# Epoch 1894/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0013 - accuracy: 0.9986
# Epoch 1895/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0013 - accuracy: 0.9985
# Epoch 1896/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 9.4082e-04 - accuracy: 0.9988
# Epoch 1897/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 9.6024e-04 - accuracy: 0.9988
# Epoch 1898/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0474 - accuracy: 0.9702
# Epoch 1899/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.1274 - accuracy: 0.9039
# Epoch 1900/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0997 - accuracy: 0.9015
# Epoch 1901/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0849 - accuracy: 0.9160
# Epoch 1902/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0782 - accuracy: 0.9220
# Epoch 1903/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0710 - accuracy: 0.9278
# Epoch 1904/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0679 - accuracy: 0.9310
# Epoch 1905/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0643 - accuracy: 0.9337
# Epoch 1906/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0613 - accuracy: 0.9393
# Epoch 1907/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0569 - accuracy: 0.9420
# Epoch 1908/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0557 - accuracy: 0.9424
# Epoch 1909/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0522 - accuracy: 0.9466
# Epoch 1910/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0500 - accuracy: 0.9497
# Epoch 1911/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0485 - accuracy: 0.9500
# Epoch 1912/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0471 - accuracy: 0.9506
# Epoch 1913/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0445 - accuracy: 0.9547
# Epoch 1914/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0417 - accuracy: 0.9587
# Epoch 1915/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0390 - accuracy: 0.9588
# Epoch 1916/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0362 - accuracy: 0.9636
# Epoch 1917/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0356 - accuracy: 0.9628
# Epoch 1918/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0342 - accuracy: 0.9657
# Epoch 1919/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0485 - accuracy: 0.9526
# Epoch 1920/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0537 - accuracy: 0.9481
# Epoch 1921/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0637 - accuracy: 0.9363
# Epoch 1922/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0735 - accuracy: 0.9270
# Epoch 1923/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0531 - accuracy: 0.9458
# Epoch 1924/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0427 - accuracy: 0.9558
# Epoch 1925/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0417 - accuracy: 0.9598
# Epoch 1926/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0307 - accuracy: 0.9697
# Epoch 1927/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0248 - accuracy: 0.9762
# Epoch 1928/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0198 - accuracy: 0.9814
# Epoch 1929/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0164 - accuracy: 0.9843
# Epoch 1930/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0149 - accuracy: 0.9862
# Epoch 1931/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0125 - accuracy: 0.9883
# Epoch 1932/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0127 - accuracy: 0.9875
# Epoch 1933/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0112 - accuracy: 0.9886
# Epoch 1934/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0105 - accuracy: 0.9900
# Epoch 1935/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0097 - accuracy: 0.9906
# Epoch 1936/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0091 - accuracy: 0.9915
# Epoch 1937/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0071 - accuracy: 0.9933
# Epoch 1938/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0074 - accuracy: 0.9931
# Epoch 1939/2000
# 17/17 [==============================] - 1s 65ms/step - loss: 0.0061 - accuracy: 0.9945
# Epoch 1940/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0139 - accuracy: 0.9872
# Epoch 1941/2000
# 17/17 [==============================] - 1s 61ms/step - loss: 0.0083 - accuracy: 0.9925
# Epoch 1942/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0114 - accuracy: 0.9883
# Epoch 1943/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0246 - accuracy: 0.9748
# Epoch 1944/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0186 - accuracy: 0.9823
# Epoch 1945/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0149 - accuracy: 0.9859
# Epoch 1946/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0111 - accuracy: 0.9896
# Epoch 1947/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0088 - accuracy: 0.9926
# Epoch 1948/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0066 - accuracy: 0.9944
# Epoch 1949/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0057 - accuracy: 0.9949
# Epoch 1950/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0053 - accuracy: 0.9948
# Epoch 1951/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0054 - accuracy: 0.9949
# Epoch 1952/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0057 - accuracy: 0.9938
# Epoch 1953/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0055 - accuracy: 0.9950
# Epoch 1954/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0041 - accuracy: 0.9959
# Epoch 1955/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0040 - accuracy: 0.9957
# Epoch 1956/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0044 - accuracy: 0.9953
# Epoch 1957/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0032 - accuracy: 0.9974
# Epoch 1958/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0036 - accuracy: 0.9964
# Epoch 1959/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0042 - accuracy: 0.9958
# Epoch 1960/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0034 - accuracy: 0.9964
# Epoch 1961/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0031 - accuracy: 0.9968
# Epoch 1962/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0027 - accuracy: 0.9976
# Epoch 1963/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0033 - accuracy: 0.9970
# Epoch 1964/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0030 - accuracy: 0.9971
# Epoch 1965/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0031 - accuracy: 0.9971
# Epoch 1966/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0033 - accuracy: 0.9966
# Epoch 1967/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0026 - accuracy: 0.9974
# Epoch 1968/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0030 - accuracy: 0.9972
# Epoch 1969/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0027 - accuracy: 0.9973
# Epoch 1970/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0025 - accuracy: 0.9976
# Epoch 1971/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0023 - accuracy: 0.9977
# Epoch 1972/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0022 - accuracy: 0.9978
# Epoch 1973/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0022 - accuracy: 0.9980
# Epoch 1974/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0024 - accuracy: 0.9976
# Epoch 1975/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0018 - accuracy: 0.9981
# Epoch 1976/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0023 - accuracy: 0.9977
# Epoch 1977/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0020 - accuracy: 0.9980
# Epoch 1978/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0024 - accuracy: 0.9977
# Epoch 1979/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0020 - accuracy: 0.9975
# Epoch 1980/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0021 - accuracy: 0.9980
# Epoch 1981/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0018 - accuracy: 0.9983
# Epoch 1982/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0019 - accuracy: 0.9983
# Epoch 1983/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0022 - accuracy: 0.9974
# Epoch 1984/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0023 - accuracy: 0.9977
# Epoch 1985/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0028 - accuracy: 0.9972
# Epoch 1986/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0026 - accuracy: 0.9972
# Epoch 1987/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0022 - accuracy: 0.9973
# Epoch 1988/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0018 - accuracy: 0.9982
# Epoch 1989/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0019 - accuracy: 0.9982
# Epoch 1990/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0015 - accuracy: 0.9984
# Epoch 1991/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0017 - accuracy: 0.9983
# Epoch 1992/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0016 - accuracy: 0.9982
# Epoch 1993/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0019 - accuracy: 0.9979
# Epoch 1994/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0014 - accuracy: 0.9985
# Epoch 1995/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0014 - accuracy: 0.9983
# Epoch 1996/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0016 - accuracy: 0.9984
# Epoch 1997/2000
# 17/17 [==============================] - 1s 64ms/step - loss: 0.0018 - accuracy: 0.9982
# Epoch 1998/2000
# 17/17 [==============================] - 1s 62ms/step - loss: 0.0015 - accuracy: 0.9985
# Epoch 1999/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0017 - accuracy: 0.9982
# Epoch 2000/2000
# 17/17 [==============================] - 1s 63ms/step - loss: 0.0014 - accuracy: 0.9986

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import keras
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
import numpy as np
import cv2
import os
import warnings
import sys
sys.stdout.write("\033[1;34m")
warnings.filterwarnings("ignore")

test_path_im='/content/drive/My Drive/test_img'
dir_path_conversation = '/content/drive/My Drive/chatterbot_dataset_ita'
test_im_len=len([name for name in os.listdir(test_path_im) if os.path.isfile(os.path.join(test_path_im, name))])
len_data_vqa=2000
data_moltiplicator=2
input_im_size=64

#questions and answers
pre_ques = ['che cosa vedi']
pre_answers = ['vedo una camera da letto', 'vedo una città con dei palazzi', 'ci sono delle persone ',
               'una foresta con degli alberi', 'sono davanti ad una montagna', 'questo potrebbe essere un cane',
               'un gatto', 'il traffico con delle macchine', 'vedo una scrivania', 'questa dovrebbe essere una sedia']
questions = []
answers = []

for i in range(len_data_vqa):
    questions.append(pre_ques[0])

for i in range(int(len_data_vqa / 200)):
    for n in range(200):
        answers.append(pre_answers[i])

for i in range(data_moltiplicator):
 for filepath in os.listdir(dir_path_conversation):
    stream = open(dir_path_conversation + os.sep + filepath, 'r', encoding='utf-8')
    text = stream.readlines()
    for i in range(int(len(text) / 2) - 6):
        questions.append(text[i + i].rstrip('\n'))
        answers.append(text[i + i + 1].rstrip('\n'))

#questions
questions_lines = questions

tokenizer = Tokenizer(oov_token=1)
tokenizer.fit_on_texts( questions_lines )
tokenized_eng_lines = tokenizer.texts_to_sequences( questions_lines )

length_list = []
for token_seq in tokenized_eng_lines:
    length_list.append( len( token_seq ))
max_input_length = np.amax( length_list )
print( 'questions max length is {}'.format( max_input_length ))

padded_eng_lines = pad_sequences( tokenized_eng_lines , maxlen=max_input_length , padding='post' )
encoder_input_data = np.array( np.expand_dims(padded_eng_lines, 1))
print( 'Encoder input data shape -> {}'.format( encoder_input_data.shape ))

eng_word_dict = tokenizer.word_index
num_eng_tokens = len( eng_word_dict )+1
print( 'Number of questions tokens = {}'.format( num_eng_tokens))

#answers
lines_answers=answers
answer_lines = []
for line in range( len(lines_answers)):
    answer_lines.append( '<START> ' + str(lines_answers[line]) + ' <END>' )

tokenizer_a = Tokenizer()
tokenizer_a.fit_on_texts( answer_lines )
tokenized_mar_lines = tokenizer_a.texts_to_sequences( answer_lines )

length_list = []
for token_seq in tokenized_mar_lines:
    length_list.append( len( token_seq ))
max_output_length = np.amax( length_list )
print( 'Answers max length is {}'.format( max_output_length ))

padded_mar_lines = pad_sequences( tokenized_mar_lines , maxlen=max_output_length, padding='post' )
decoder_input_data = np.array( padded_mar_lines )
print( 'Decoder input data shape -> {}'.format( decoder_input_data.shape ))

mar_word_dict = tokenizer_a.word_index
num_mar_tokens = len( mar_word_dict )+1
print( 'Number of Answers tokens = {}'.format( num_mar_tokens))

#load model
enc_model=keras.models.load_model('/content/enc_model.h5',compile=False)
dec_model=keras.models.load_model('/content/dec_model.h5',compile=False)

print('Test su seq2se2_cnn avviato...')

while True:
 number_file=input('Scegliere il numero del file:')
 try:
   if int(number_file)>test_im_len or int(number_file)<1:
     print('File non trovato, riprova.')
   else:
     image=cv2.resize(cv2.imread(test_path_im+'/'+ str(number_file)+ '.jpg'),(input_im_size,input_im_size))/255.0
     image=np.expand_dims([image],1)
     question=input('Tu:')
     question=pad_sequences(tokenizer.texts_to_sequences([question]), maxlen=max_input_length , padding='post')
     question=np.expand_dims(question,1)
     states_values = enc_model.predict([image,question])
     empty_target_seq = np.zeros((1, 1))
     empty_target_seq[0, 0] = mar_word_dict['start']
     stop_condition = False
     decoded_translation = ''
     while not stop_condition:
       dec_outputs, h, c = dec_model.predict([empty_target_seq] + states_values)
       sampled_word_index = np.argmax(dec_outputs[0, -1, :])
       sampled_word = None
       for word, index in mar_word_dict.items():
         if sampled_word_index == index:
           decoded_translation += ' {}'.format(word)
           sampled_word = word

       if sampled_word == 'end' or len(decoded_translation.split()) > max_output_length:
         stop_condition = True

       empty_target_seq = np.zeros((1, 1))
       empty_target_seq[0, 0] = sampled_word_index
       states_values = [h, c]

     print('AGI:' + decoded_translation.replace('end',''))
 except ValueError:
   print("Si accettano solo numeri.")
